# %%
import pandas as pd
import os

# %%
df = pd.read_csv("../data/all_dataset_description.csv")

# %%
query = "climate change"

# %%
df.shape
# Out:
# (5690, 21)

# %%
df["description"] = df["description"].fillna("")
df[df["description"].str.contains(query)]
# Out:
#       Unnamed: 0    did                               name  version  uploader  \
# 3546        3546  43351  Temperature-Readings--IOT-Devices        1     30126
# 3677        3677  43486         Bike-Sharing-Washington-DC        1     30126
# 3950        3950  43765           CDP-Challenge-Cities-KPI        1     30123
# 3991        3991  43806       Rainfall-in-Kerala-1901-2017        1     30125
#
#       status format  MajorityClassSize  MaxNominalAttDistinctValues  \
# 3546  active   arff                NaN                          NaN
# 3677  active   arff                NaN                          NaN
# 3950  active   arff                NaN                          NaN
# 3991  active   arff                NaN                          NaN
#
#       MinorityClassSize  ...  NumberOfFeatures  NumberOfInstances  \
# 3546                NaN  ...               5.0            97606.0
# 3677                NaN  ...              29.0             2922.0
# ...

# %%
df[df["did"] == 43613]
# Out:
#       Unnamed: 0    did                name  version  uploader  status format  \
# 3802        3802  43613  Sample-of-Car-Data        1     30123  active   arff
#
#       MajorityClassSize  MaxNominalAttDistinctValues  MinorityClassSize  ...  \
# 3802                NaN                          NaN                NaN  ...
#
#       NumberOfFeatures  NumberOfInstances  NumberOfInstancesWithMissingValues  \
# 3802              23.0              205.0                                 8.0
#
#       NumberOfMissingValues  NumberOfNumericFeatures  \
# 3802                   10.0                     10.0
#
#       NumberOfSymbolicFeatures  \
# 3802                       0.0
#
#                                             description  \
# 3802  Context\nThere's a story behind every dataset ...
#
#                                               qualities  \
# 3802  AutoCorrelation : nan, Dimensionality : 0.1121...
#
#                                                features  \
# ...

# %%
# row where len description < 10
df[df['description'].str.len() < 10]
# Out:
#       Unnamed: 0    did                     name  version  uploader  status  \
# 2457        2457  40678                     led7        1       869  active
# 2459        2459  40681                     mux6        1       869  active
# 2479        2479  40713                      dis        1       869  active
# 2485        2485  40869  pathogen_survey_dataset        3      3508  active
# 2497        2497  40967                 feedback        1      4232  active
# ...          ...    ...                      ...      ...       ...     ...
# 5578        5578  46128       car_rental_process        4     42802  active
# 5579        5579  46129       car_rental_process        5     42802  active
# 5633        5633  46187                test_surv        1     30127  active
# 5684        5684  46253                     MCAD        1     38557  active
# 5687        5687  46258                    sonar        2     43180  active
#
# ...

# %%
df[df["name"] == "mushroom"]
# Out:
#       Unnamed: 0    did      name  version  uploader  status format  \
# 19            19     24  mushroom        1         1  active   ARFF
# 4071        4071  43922  mushroom        3     30861  active   ARFF
# 4072        4072  43923  mushroom        4     30861  active   ARFF
#
#       MajorityClassSize  MaxNominalAttDistinctValues  MinorityClassSize  ...  \
# 19               4208.0                         12.0             3916.0  ...
# 4071             4208.0                          NaN             3916.0  ...
# 4072             4320.0                          NaN                2.0  ...
#
#       NumberOfFeatures  NumberOfInstances  NumberOfInstancesWithMissingValues  \
# 19                23.0             8124.0                              2480.0
# 4071              23.0             8124.0                                 0.0
# 4072               9.0            12960.0                                 0.0
#
#       NumberOfMissingValues  NumberOfNumericFeatures  \
# ...
